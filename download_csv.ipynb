# %%
## 通过Akshare库下载数据，并对它进行分析

# %%
import akshare as ak

# %%
stock_sh000001=ak.stock_zh_a_daily(symbol='sh000001',start_date='20100101')

# %%
stock_sh000001
# Out:
#                open     high      low    close        volume  \
# date
# 2010-01-04  3289.75  3295.28  3243.32  3243.76  1.094479e+10
# 2010-01-05  3254.47  3290.51  3221.46  3282.18  1.261151e+10
# 2010-01-06  3277.52  3295.87  3253.04  3254.22  1.236514e+10
# 2010-01-07  3253.99  3268.82  3176.71  3192.78  1.286528e+10
# 2010-01-08  3177.26  3198.92  3149.02  3196.00  9.837714e+09
# ...             ...      ...      ...      ...           ...
# 2021-05-17  3490.41  3530.51  3490.14  3517.62  3.221360e+10
# 2021-05-18  3520.65  3529.01  3510.86  3529.01  2.713086e+10
# 2021-05-19  3521.11  3521.11  3503.82  3510.96  2.783211e+10
# 2021-05-20  3500.88  3517.74  3486.07  3506.94  3.260093e+10
# 2021-05-21  3510.84  3518.38  3479.67  3486.56  2.838263e+10
#
#             outstanding_share  turnover
# date
# 2010-01-04       2.924114e+09  3.742943
# 2010-01-05       2.924114e+09  4.312932
# 2010-01-06       2.924114e+09  4.228678
# 2010-01-07       2.924114e+09  4.399719
# ...

# %%
stock_sh000001.to_csv('sh000001.csv',encoding='utf_8_sig')
